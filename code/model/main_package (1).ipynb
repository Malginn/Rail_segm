# %% [markdown]
# ## попробовать сейчас на обучении ее в исходным размерах, если нет, то добавить картинки с контр примерами туда еще и разметить остальнгые переключатели

# %%
# import shutil
# shutil.make_archive('train_img_gen', 'zip', '/content/train_img_gen')
# Out:
# '/content/train_img_gen.zip'

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/yolo_667_big.zip' -d '/content/'
# Out:
# Archive:  /content/drive/MyDrive/yolo_667_big.zip
# replace /content/YOLO_dataset/data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/YOLO_dataset/data.yaml
#   inflating: /content/YOLO_dataset/train/images/rs05840.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05842.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05849.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05862.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05863.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05868.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05872.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05877.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05889.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05895.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05898.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05900.jpg
#   inflating: /content/YOLO_dataset/train/images/rs05905.jpg
# ...

# %%
from IPython.display import display, Image
import torch, torchvision


# !pip install ultralytics
# display.clear_output()
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
torch.zeros(1).cuda()
# Out:
# tensor([0.], device='cuda:0')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install ultralytics

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from ultralytics import YOLO

from shapely.geometry import Polygon
import cv2

import os
import locale
print(locale.getpreferredencoding())

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# utf-8

# %%
def getpreferredencoding(do_setlocale = True):
    """
    Для корректного чтения файлов .npy
    """
    return "UTF-8"

locale.getpreferredencoding = getpreferredencoding
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
torch.cuda.empty_cache()

# %%
model = YOLO(r"C:\Users\ivano\Документы\GitHub\Rail_segm\code\model\best_models\best_0.65.pt")
# model.info()

results = model.train(data=r"C:\Users\ivano\Документы\GitHub\Rail_segm\code\gen_dataset\YOLO_dataset\data.yaml", epochs=30, imgsz=(1080, 1920),  workers=0, show_labels=False, batch=5)

# results = model('results/bus.jpg')
# Out:
# New https://pypi.org/project/ultralytics/8.1.23 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.5 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.5 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning C:\Users\ivano\Документы\GitHub\Rail_segm\code\gen_dataset\YOLO_dataset\validation\labels.cache... 345 images, 0 backgrounds, 0 corrupt: 100%|██████████| 345/345 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 69/69 [00:17<00:00,  4.03it/s]
#                    all        345        588      0.659      0.565      0.579      0.243      0.656       0.56      0.557      0.237
# Speed: 0.8ms preprocess, 16.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\segment\train252

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### В данном случае нас интересуют: `IoU`, `mAP50`, `loss`,
#
# Дальше, когда будут доабвляться классы, будет важен `класс-специфичный AP`, т.е. метрика AP для каждого класса

# %%
# metrics.box.map    # map50-95(B)
# metrics.box.map50  # map50(B)
# metrics.box.map75  # map75(B)
# metrics.box.maps   # a list contains map50-95(B) of each category
metrics.seg.map    # map50-95(M)
metrics.seg.map50  # map50(M)
# metrics.seg.map75  # map75(M)
# metrics.seg.maps   # a list contains map50-95(M) of each category
# Out:
# 0.39567718356014286

# %% [markdown]
# #обучим на кастомном датасете

# %%
pred = model.predict('/content/YOLO_dataset/train/images/rs05840.jpg', iou=0.2, show_labels=True, save=True, imgsz=1920, conf=0.2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pred = model.predict('/content/YOLO_dataset/train/images/rs05840.jpg', iou=0.2, show_labels=True, save=True, imgsz=1920, conf=0.2)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\model.py:429, in Model.predict(self, source, stream, predictor, **kwargs)
#     427 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     428     self.predictor.set_prompts(prompts)
# --> 429 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:204, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     202     return self.stream_inference(source, model, *args, **kwargs)
#     203 else:
# ...

# %%
train_img_path = '/content/train_img_gen'
train_labels_path = '/content/train_img_gen/labels'
os.makedirs('/content/train_img_gen/labels')

# %%
directory = '/content/bboxes_train'
img_list = os.listdir(directory)

for img_name in img_list[:5]:
  img_path = directory + '/'+ img_name
  # print(img_path)
  img = cv2.imread(img_path)
  img_copy = img

  h, w, _ = img.shape
  results = model.predict(img, conf=0.45)

  mask = results[0].masks[0].xy
  cls = results[0].boxes.cls.tolist()
  annot_lines = []
  annotation = f'{list(mask)}'

  cv2.imwrite(os.path.join(train_img_path, img_name), img_copy)

  img_txt = img_name.replace('.jpg', '.txt')
  with open(f'{train_labels_path}/{img_txt}', 'w') as file:
    file.write(annotation)
    file.write('\n')

print(img_path)
# Out:
# 0: 96x128 1 switch, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 2.8ms postprocess per image at shape (1, 3, 96, 128)
#
# 0: 96x128 1 switch, 18.6ms
# Speed: 0.4ms preprocess, 18.6ms inference, 2.6ms postprocess per image at shape (1, 3, 96, 128)
#
# 0: 64x128 1 switch, 13.7ms
# Speed: 0.6ms preprocess, 13.7ms inference, 2.3ms postprocess per image at shape (1, 3, 64, 128)
#
# 0: 64x128 1 switch, 12.5ms
# Speed: 0.7ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 64, 128)
#
# 0: 96x128 1 switch, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 96, 128)
# /content/bboxes_train/rs00194_4.jpg

# %%
# !zip -r '/content/train_img_gen'
# Out:
# zip error: Nothing to do! (/content/train_img_gen.zip)

# %%
shutil.rmtree(data='/content/train_img_gen/labels')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-6a28ea265452> in <cell line: 1>()
# ----> 1 shutil.rmtree(data='/content/train_img_gen/labels', epochs=50, imgsz=1900,  workers=0, show_labels=False, batch=32)
#
# TypeError: rmtree() got an unexpected keyword argument 'data'

# %% [markdown]
# ## Расчет метрики IoU
# ### Я не нашел в документации того, как считать метрику, поэтому будем считать ее вручную

# %%
image_path = '/content/YOLO_dataset/train/images/rs00578.jpg'

mask_pred, _ = extract_pred_masks(image_path)

# %%
def yolomask_to_numpy(file_path):
    """
    Чтение и трансформация маски yolo в массив numpy

    input -> one-annotation-file
    output -> return masks_true_numpy without one dimension
    """
    with open() as file:
      data = file.read()

    arr_data_str = data.split('\n')
    masks_true = np.array([np.array(item.split(' ')).astype(float) for item in arr_data_str[:-1]])

    print(masks_true.shape)
# Out:
# (4, 9)

# %% [markdown]
# ## Якобы мы вытащили полигоны из аннотации и предикта, по функции iou и конвертации в RLE мы посчитали занчени IoU метрики, но точность = 0.0, будем разбираться дальше

# %% [markdown]
# # нужно перевести предикты модели в то что подается на вход

# %%
from ultralytics.data.utils import polygon2mask
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/YOLO_dataset/train/images/rs05840.jpg")

polygon_scaled =[
                    731.0,
                    560.0,
                    731.0,
                    562.0,
                    733.0,
                    562.0,
                    734.0,
                    563.0,
                    734.0,
                    565.0,
                    736.0,
                    567.0,
                    737.0,
                    567.0,
                    738.0,
                    568.0,
                    740.0,
                    568.0,
                    741.0,
                    569.0,
                    743.0,
                    569.0,
                    748.0,
                    574.0,
                    748.0,
                    576.0,
                    749.0,
                    577.0,
                    749.0,
                    578.0,
                    746.0,
                    581.0,
                    745.0,
                    581.0,
                    742.0,
                    584.0,
                    741.0,
                    584.0,
                    739.0,
                    586.0,
                    738.0,
                    586.0,
                    737.0,
                    587.0,
                    736.0,
                    587.0,
                    735.0,
                    588.0,
                    734.0,
                    588.0,
                    733.0,
                    589.0,
                    732.0,
                    589.0,
                    731.0,
                    590.0,
                    730.0,
                    590.0,
                    729.0,
                    591.0,
                    728.0,
                    591.0,
                    727.0,
                    592.0,
                    727.0,
                    601.0,
                    740.0,
                    601.0,
                    741.0,
                    600.0,
                    742.0,
                    601.0,
                    785.0,
                    601.0,
                    786.0,
                    600.0,
                    787.0,
                    600.0,
                    788.0,
                    601.0,
                    793.0,
                    601.0,
                    794.0,
                    600.0,
                    799.0,
                    600.0,
                    800.0,
                    599.0,
                    802.0,
                    599.0,
                    802.0,
                    586.0,
                    798.0,
                    586.0,
                    797.0,
                    587.0,
                    793.0,
                    587.0,
                    792.0,
                    588.0,
                    789.0,
                    588.0,
                    788.0,
                    589.0,
                    783.0,
                    589.0,
                    782.0,
                    590.0,
                    781.0,
                    590.0,
                    780.0,
                    591.0,
                    778.0,
                    591.0,
                    777.0,
                    590.0,
                    778.0,
                    589.0,
                    778.0,
                    588.0,
                    779.0,
                    587.0,
                    780.0,
                    587.0,
                    782.0,
                    585.0,
                    783.0,
                    585.0,
                    784.0,
                    584.0,
                    784.0,
                    583.0,
                    785.0,
                    582.0,
                    786.0,
                    582.0,
                    787.0,
                    581.0,
                    788.0,
                    581.0,
                    789.0,
                    580.0,
                    790.0,
                    580.0,
                    791.0,
                    579.0,
                    792.0,
                    579.0,
                    798.0,
                    573.0,
                    799.0,
                    573.0,
                    801.0,
                    571.0,
                    802.0,
                    571.0,
                    802.0,
                    560.0,
                    783.0,
                    560.0,
                    783.0,
                    561.0,
                    781.0,
                    563.0,
                    780.0,
                    563.0,
                    778.0,
                    565.0,
                    777.0,
                    565.0,
                    776.0,
                    566.0,
                    774.0,
                    566.0,
                    773.0,
                    567.0,
                    770.0,
                    567.0,
                    769.0,
                    566.0,
                    764.0,
                    566.0,
                    763.0,
                    565.0,
                    763.0,
                    564.0,
                    761.0,
                    564.0,
                    760.0,
                    565.0,
                    759.0,
                    564.0,
                    756.0,
                    564.0,
                    755.0,
                    563.0,
                    755.0,
                    562.0,
                    756.0,
                    561.0,
                    756.0,
                    560.0,
                    734.0,
                    560.0,
                    733.0,
                    561.0,
                    732.0,
                    560.0
                ]

imgsz = image.shape[:2]
polygon = np.array(
    polygon_scaled,
)



mask = polygon2mask(
    imgsz,     # tuple
    [polygon], # input as list
    color=255, # 8-bit binary
    downsample_ratio=1
)


# Отобразить изображение и сегментированное изображение в консоли
cv2_imshow(image)
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
# <PIL.Image.Image image mode=L size=1920x1080>
