# %% [markdown]
# # Создание модели для сегментации объектов на железнодорожных путях
#
# - у нас есть стрелки(switches) - пошерстные и противошерстные
# - нам мужно собрать качественные данные
# - подобрать архитекутры
# - создать модель и протестировать ее на видео объекктах
#
# Yolov8-seg, sam
#
# Классы:
# 1) поиск стрелок
# 2) шерстные противошертсные
# 3) 2 + люди
# 4) 3 + рельсы
